# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import random
from citipy import citipy
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 764

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6fde90232665e52dcae826d1d0c62ee0

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_current = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_current})
                         

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | cayenne
# Processing Record 2 of Set 1 | sabang
# Processing Record 3 of Set 1 | ushuaia
# Processing Record 4 of Set 1 | meulaboh
# Processing Record 5 of Set 1 | hualmay
# Processing Record 6 of Set 1 | qaanaaq
# Processing Record 7 of Set 1 | bara
# Processing Record 8 of Set 1 | faanui
# Processing Record 9 of Set 1 | sao joao do piaui
# Processing Record 10 of Set 1 | hithadhoo
# Processing Record 11 of Set 1 | omsukchan
# Processing Record 12 of Set 1 | kodiak
# Processing Record 13 of Set 1 | hirosaki
# Processing Record 14 of Set 1 | sola
# Processing Record 15 of Set 1 | atuona
# Processing Record 16 of Set 1 | neuruppin
# Processing Record 17 of Set 1 | shieli
# Processing Record 18 of Set 1 | puerto ayora
# Processing Record 19 of Set 1 | saint-philippe
# Processing Record 20 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 21 of Set 1 | cidreira
# Processing Record 22 of Set 1 | pevek
# Processing Record 23 of Set 1 | georgetown
# Processing Record 24 of Set 1 | busselton
# Processing Record 25 of Set 1 | bargal
# City not found. Skipping...
# Processing Record 26 of Set 1 | saleaula
# City not found. Skipping...
# Processing Record 27 of Set 1 | alofi
# Processing Record 28 of Set 1 | idrinskoye
# Processing Record 29 of Set 1 | caimito
# Processing Record 30 of Set 1 | carnarvon
# Processing Record 31 of Set 1 | rikitea
# Processing Record 32 of Set 1 | new norfolk
# Processing Record 33 of Set 1 | hobart
# Processing Record 34 of Set 1 | pangnirtung
# Processing Record 35 of Set 1 | semnan
# Processing Record 36 of Set 1 | alice springs
# Processing Record 37 of Set 1 | sioux lookout
# Processing Record 38 of Set 1 | grand gaube
# Processing Record 39 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 40 of Set 1 | punta arenas
# Processing Record 41 of Set 1 | washougal
# Processing Record 42 of Set 1 | san andres
# Processing Record 43 of Set 1 | vaini
# Processing Record 44 of Set 1 | mataura
# Processing Record 45 of Set 1 | touros
# Processing Record 46 of Set 1 | beyneu
# Processing Record 47 of Set 1 | lagoa
# Processing Record 48 of Set 1 | albany
# Processing Record 49 of Set 1 | tuktoyaktuk
# Processing Record 50 of Set 1 | castro
# Processing Record 1 of Set 2 | mae sot
# Processing Record 2 of Set 2 | mount isa
# Processing Record 3 of Set 2 | kirovskiy
# Processing Record 4 of Set 2 | nakhodka
# Processing Record 5 of Set 2 | valparaiso
# Processing Record 6 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 7 of Set 2 | samarai
# Processing Record 8 of Set 2 | havoysund
# Processing Record 9 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 10 of Set 2 | mar del plata
# Processing Record 11 of Set 2 | nkowakowa
# Processing Record 12 of Set 2 | jinchang
# Processing Record 13 of Set 2 | ossora
# Processing Record 14 of Set 2 | saskylakh
# Processing Record 15 of Set 2 | jamestown
# Processing Record 16 of Set 2 | hilo
# Processing Record 17 of Set 2 | kentville
# Processing Record 18 of Set 2 | natchitoches
# Processing Record 19 of Set 2 | omboue
# Processing Record 20 of Set 2 | fortuna
# Processing Record 21 of Set 2 | virginia beach
# Processing Record 22 of Set 2 | ahipara
# Processing Record 23 of Set 2 | khatanga
# Processing Record 24 of Set 2 | muros
# Processing Record 25 of Set 2 | dikson
# Processing Record 26 of Set 2 | ilulissat
# Processing Record 27 of Set 2 | karaul
# City not found. Skipping...
# Processing Record 28 of Set 2 | richards bay
# Processing Record 29 of Set 2 | rockhampton
# Processing Record 30 of Set 2 | kavieng
# Processing Record 31 of Set 2 | yatou
# Processing Record 32 of Set 2 | butaritari
# Processing Record 33 of Set 2 | douglas
# Processing Record 34 of Set 2 | vila velha
# Processing Record 35 of Set 2 | tongsa
# City not found. Skipping...
# Processing Record 36 of Set 2 | santa cruz de la palma
# Processing Record 37 of Set 2 | nevel
# Processing Record 38 of Set 2 | severo-kurilsk
# Processing Record 39 of Set 2 | berbera
# Processing Record 40 of Set 2 | saint george
# Processing Record 41 of Set 2 | bethel
# Processing Record 42 of Set 2 | ponta do sol
# Processing Record 43 of Set 2 | port alfred
# Processing Record 44 of Set 2 | longyearbyen
# Processing Record 45 of Set 2 | praia da vitoria
# Processing Record 46 of Set 2 | bayir
# Processing Record 47 of Set 2 | port elizabeth
# Processing Record 48 of Set 2 | ust-nera
# Processing Record 49 of Set 2 | riyadh
# Processing Record 50 of Set 2 | iskenderun
# Processing Record 1 of Set 3 | tidore
# City not found. Skipping...
# Processing Record 2 of Set 3 | victor harbor
# Processing Record 3 of Set 3 | dingle
# Processing Record 4 of Set 3 | hasaki
# Processing Record 5 of Set 3 | ampanihy
# Processing Record 6 of Set 3 | cartagena del chaira
# Processing Record 7 of Set 3 | camabatela
# Processing Record 8 of Set 3 | te anau
# Processing Record 9 of Set 3 | campbell river
# Processing Record 10 of Set 3 | tasiilaq
# Processing Record 11 of Set 3 | byron bay
# Processing Record 12 of Set 3 | faya
# Processing Record 13 of Set 3 | nikolskoye
# Processing Record 14 of Set 3 | tanggu
# Processing Record 15 of Set 3 | saint-pierre
# Processing Record 16 of Set 3 | klyuchi
# Processing Record 17 of Set 3 | boulder city
# Processing Record 18 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 19 of Set 3 | nanortalik
# Processing Record 20 of Set 3 | martinsville
# Processing Record 21 of Set 3 | shelburne
# Processing Record 22 of Set 3 | sorland
# Processing Record 23 of Set 3 | thompson
# Processing Record 24 of Set 3 | iqaluit
# Processing Record 25 of Set 3 | bambous virieux
# Processing Record 26 of Set 3 | kadykchan
# City not found. Skipping...
# Processing Record 27 of Set 3 | kamenka
# Processing Record 28 of Set 3 | kinablangan
# Processing Record 29 of Set 3 | turukhansk
# Processing Record 30 of Set 3 | paamiut
# Processing Record 31 of Set 3 | avarua
# Processing Record 32 of Set 3 | souillac
# Processing Record 33 of Set 3 | tiksi
# Processing Record 34 of Set 3 | mazyr
# Processing Record 35 of Set 3 | saint-augustin
# Processing Record 36 of Set 3 | salalah
# Processing Record 37 of Set 3 | tuatapere
# Processing Record 38 of Set 3 | burnie
# Processing Record 39 of Set 3 | lianran
# Processing Record 40 of Set 3 | oranjemund
# Processing Record 41 of Set 3 | chandbali
# Processing Record 42 of Set 3 | gordeyevka
# Processing Record 43 of Set 3 | talnakh
# Processing Record 44 of Set 3 | komsomolskiy
# Processing Record 45 of Set 3 | moche
# Processing Record 46 of Set 3 | sitka
# Processing Record 47 of Set 3 | vung tau
# Processing Record 48 of Set 3 | bethanien
# Processing Record 49 of Set 3 | palaikastron
# Processing Record 50 of Set 3 | constitucion
# Processing Record 1 of Set 4 | yellowknife
# Processing Record 2 of Set 4 | kapaa
# Processing Record 3 of Set 4 | wulanhaote
# City not found. Skipping...
# Processing Record 4 of Set 4 | aden
# Processing Record 5 of Set 4 | ambilobe
# Processing Record 6 of Set 4 | mount gambier
# Processing Record 7 of Set 4 | codrington
# Processing Record 8 of Set 4 | saldanha
# Processing Record 9 of Set 4 | pisco
# Processing Record 10 of Set 4 | cape town
# Processing Record 11 of Set 4 | arraial do cabo
# Processing Record 12 of Set 4 | shakhovskaya
# Processing Record 13 of Set 4 | marcona
# City not found. Skipping...
# Processing Record 14 of Set 4 | avera
# Processing Record 15 of Set 4 | hermanus
# Processing Record 16 of Set 4 | naica
# Processing Record 17 of Set 4 | bredasdorp
# Processing Record 18 of Set 4 | olafsvik
# Processing Record 19 of Set 4 | southampton
# Processing Record 20 of Set 4 | provideniya
# Processing Record 21 of Set 4 | fare
# Processing Record 22 of Set 4 | torbay
# Processing Record 23 of Set 4 | hambantota
# Processing Record 24 of Set 4 | sao filipe
# Processing Record 25 of Set 4 | jandaia do sul
# Processing Record 26 of Set 4 | kohlu
# Processing Record 27 of Set 4 | xiantao
# Processing Record 28 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 29 of Set 4 | mahebourg
# Processing Record 30 of Set 4 | launceston
# Processing Record 31 of Set 4 | khani
# Processing Record 32 of Set 4 | victoria
# Processing Record 33 of Set 4 | kruisfontein
# Processing Record 34 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 35 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 36 of Set 4 | havre-saint-pierre
# Processing Record 37 of Set 4 | chokurdakh
# Processing Record 38 of Set 4 | jumla
# Processing Record 39 of Set 4 | vilcun
# Processing Record 40 of Set 4 | vao
# Processing Record 41 of Set 4 | tasbuget
# City not found. Skipping...
# Processing Record 42 of Set 4 | nagato
# Processing Record 43 of Set 4 | port hardy
# Processing Record 44 of Set 4 | yicheng
# Processing Record 45 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 46 of Set 4 | cabo san lucas
# Processing Record 47 of Set 4 | scottsbluff
# Processing Record 48 of Set 4 | kosh-agach
# Processing Record 49 of Set 4 | barrow
# Processing Record 50 of Set 4 | coroata
# Processing Record 1 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 2 of Set 5 | krasnyy chikoy
# Processing Record 3 of Set 5 | mecca
# Processing Record 4 of Set 5 | sterling
# Processing Record 5 of Set 5 | yerbogachen
# Processing Record 6 of Set 5 | migori
# Processing Record 7 of Set 5 | elizabeth city
# Processing Record 8 of Set 5 | vila
# Processing Record 9 of Set 5 | wajid
# Processing Record 10 of Set 5 | ostrovnoy
# Processing Record 11 of Set 5 | tsienyane
# City not found. Skipping...
# Processing Record 12 of Set 5 | lundazi
# Processing Record 13 of Set 5 | ciucsangeorgiu
# Processing Record 14 of Set 5 | delyatyn
# Processing Record 15 of Set 5 | pontianak
# Processing Record 16 of Set 5 | bengkulu
# Processing Record 17 of Set 5 | tayu
# Processing Record 18 of Set 5 | ambon
# Processing Record 19 of Set 5 | college
# Processing Record 20 of Set 5 | norman wells
# Processing Record 21 of Set 5 | kaitangata
# Processing Record 22 of Set 5 | mitzic
# Processing Record 23 of Set 5 | bluff
# Processing Record 24 of Set 5 | port macquarie
# Processing Record 25 of Set 5 | flinders
# Processing Record 26 of Set 5 | skorodnoye
# Processing Record 27 of Set 5 | kalmunai
# Processing Record 28 of Set 5 | vytegra
# Processing Record 29 of Set 5 | palabuhanratu
# City not found. Skipping...
# Processing Record 30 of Set 5 | toliary
# City not found. Skipping...
# Processing Record 31 of Set 5 | puerto madryn
# Processing Record 32 of Set 5 | clifton
# Processing Record 33 of Set 5 | mancio lima
# Processing Record 34 of Set 5 | khilok
# Processing Record 35 of Set 5 | lorengau
# Processing Record 36 of Set 5 | geraldton
# Processing Record 37 of Set 5 | mujiayingzi
# Processing Record 38 of Set 5 | mazagao
# Processing Record 39 of Set 5 | kungurtug
# Processing Record 40 of Set 5 | bafoulabe
# Processing Record 41 of Set 5 | yamada
# Processing Record 42 of Set 5 | odienne
# Processing Record 43 of Set 5 | lira
# Processing Record 44 of Set 5 | maldonado
# Processing Record 45 of Set 5 | arlit
# Processing Record 46 of Set 5 | dunedin
# Processing Record 47 of Set 5 | kutum
# Processing Record 48 of Set 5 | birjand
# Processing Record 49 of Set 5 | pimentel
# Processing Record 50 of Set 5 | doha
# Processing Record 1 of Set 6 | la ronge
# Processing Record 2 of Set 6 | sistranda
# Processing Record 3 of Set 6 | saint-ambroise
# Processing Record 4 of Set 6 | sidi ali
# Processing Record 5 of Set 6 | nome
# Processing Record 6 of Set 6 | indiaroba
# Processing Record 7 of Set 6 | sungairaya
# Processing Record 8 of Set 6 | ukiah
# Processing Record 9 of Set 6 | eyl
# Processing Record 10 of Set 6 | yuza
# Processing Record 11 of Set 6 | araouane
# Processing Record 12 of Set 6 | ise
# Processing Record 13 of Set 6 | buxtehude
# Processing Record 14 of Set 6 | mudgee
# Processing Record 15 of Set 6 | tambura
# Processing Record 16 of Set 6 | sarankhola
# Processing Record 17 of Set 6 | lodja
# Processing Record 18 of Set 6 | matara
# Processing Record 19 of Set 6 | vardo
# Processing Record 20 of Set 6 | troitskoye
# Processing Record 21 of Set 6 | itarema
# Processing Record 22 of Set 6 | kedrovyy
# Processing Record 23 of Set 6 | nuevo progreso
# Processing Record 24 of Set 6 | biak
# Processing Record 25 of Set 6 | kadhan
# Processing Record 26 of Set 6 | bambanglipuro
# Processing Record 27 of Set 6 | upernavik
# Processing Record 28 of Set 6 | chuy
# Processing Record 29 of Set 6 | tilichiki
# Processing Record 30 of Set 6 | dzerzhinsk
# Processing Record 31 of Set 6 | louisbourg
# City not found. Skipping...
# Processing Record 32 of Set 6 | markova
# Processing Record 33 of Set 6 | lebedinyy
# Processing Record 34 of Set 6 | comodoro rivadavia
# Processing Record 35 of Set 6 | deputatskiy
# Processing Record 36 of Set 6 | pangkalanbuun
# Processing Record 37 of Set 6 | manzil tamim
# City not found. Skipping...
# Processing Record 38 of Set 6 | prince rupert
# Processing Record 39 of Set 6 | dharchula
# Processing Record 40 of Set 6 | wanderlandia
# City not found. Skipping...
# Processing Record 41 of Set 6 | samusu
# City not found. Skipping...
# Processing Record 42 of Set 6 | quelimane
# Processing Record 43 of Set 6 | grand river south east
# City not found. Skipping...
# Processing Record 44 of Set 6 | hellvik
# Processing Record 45 of Set 6 | bandar-e torkaman
# City not found. Skipping...
# Processing Record 46 of Set 6 | brewster
# Processing Record 47 of Set 6 | ulaangom
# Processing Record 48 of Set 6 | bystryy istok
# Processing Record 49 of Set 6 | hamilton
# Processing Record 50 of Set 6 | tual
# Processing Record 1 of Set 7 | dondo
# Processing Record 2 of Set 7 | kotido
# Processing Record 3 of Set 7 | roald
# Processing Record 4 of Set 7 | lircay
# Processing Record 5 of Set 7 | kuppam
# Processing Record 6 of Set 7 | verkhnevilyuysk
# Processing Record 7 of Set 7 | north bend
# Processing Record 8 of Set 7 | vestmannaeyjar
# Processing Record 9 of Set 7 | yulara
# Processing Record 10 of Set 7 | skibbereen
# Processing Record 11 of Set 7 | aranos
# Processing Record 12 of Set 7 | helena
# Processing Record 13 of Set 7 | caravelas
# Processing Record 14 of Set 7 | boa vista
# Processing Record 15 of Set 7 | maragogi
# Processing Record 16 of Set 7 | tapaua
# City not found. Skipping...
# Processing Record 17 of Set 7 | jalgaon
# Processing Record 18 of Set 7 | taoudenni
# Processing Record 19 of Set 7 | razole
# Processing Record 20 of Set 7 | kerema
# Processing Record 21 of Set 7 | nouadhibou
# Processing Record 22 of Set 7 | ouadda
# Processing Record 23 of Set 7 | petropavlovsk-kamchatskiy
# Processing Record 24 of Set 7 | gizo
# Processing Record 25 of Set 7 | airai
# Processing Record 26 of Set 7 | east london
# Processing Record 27 of Set 7 | chikwawa
# Processing Record 28 of Set 7 | zyryanka
# Processing Record 29 of Set 7 | shaoyang
# Processing Record 30 of Set 7 | anshun
# Processing Record 31 of Set 7 | werdohl
# Processing Record 32 of Set 7 | vila do maio
# Processing Record 33 of Set 7 | adwa
# Processing Record 34 of Set 7 | tucurui
# Processing Record 35 of Set 7 | mvuma
# Processing Record 36 of Set 7 | cockburn town
# Processing Record 37 of Set 7 | brooks
# Processing Record 38 of Set 7 | lebu
# Processing Record 39 of Set 7 | khor
# Processing Record 40 of Set 7 | santa lucia
# Processing Record 41 of Set 7 | gadarwara
# Processing Record 42 of Set 7 | grand centre
# City not found. Skipping...
# Processing Record 43 of Set 7 | svetlaya
# Processing Record 44 of Set 7 | uwayl
# City not found. Skipping...
# Processing Record 45 of Set 7 | anadyr
# Processing Record 46 of Set 7 | niamey
# Processing Record 47 of Set 7 | somerset east
# Processing Record 48 of Set 7 | san cristobal
# Processing Record 49 of Set 7 | rancho mirage
# Processing Record 50 of Set 7 | kearny
# Processing Record 1 of Set 8 | gaspe
# Processing Record 2 of Set 8 | smithers
# Processing Record 3 of Set 8 | huntsville
# Processing Record 4 of Set 8 | luderitz
# Processing Record 5 of Set 8 | maceio
# Processing Record 6 of Set 8 | cairns
# Processing Record 7 of Set 8 | fomboni
# Processing Record 8 of Set 8 | gamba
# Processing Record 9 of Set 8 | bama
# Processing Record 10 of Set 8 | oktyabrskiy
# Processing Record 11 of Set 8 | ancud
# Processing Record 12 of Set 8 | miragoane
# Processing Record 13 of Set 8 | lexington
# Processing Record 14 of Set 8 | chiang klang
# Processing Record 15 of Set 8 | axim
# Processing Record 16 of Set 8 | choix
# Processing Record 17 of Set 8 | kudat
# Processing Record 18 of Set 8 | tessalit
# Processing Record 19 of Set 8 | powassan
# Processing Record 20 of Set 8 | laguna
# Processing Record 21 of Set 8 | helong
# Processing Record 22 of Set 8 | sidney
# Processing Record 23 of Set 8 | namatanai
# Processing Record 24 of Set 8 | mogadishu
# Processing Record 25 of Set 8 | alta floresta
# Processing Record 26 of Set 8 | beringovskiy
# Processing Record 27 of Set 8 | vostok
# Processing Record 28 of Set 8 | ankara
# Processing Record 29 of Set 8 | yaan
# Processing Record 30 of Set 8 | camocim
# Processing Record 31 of Set 8 | cherskiy
# Processing Record 32 of Set 8 | berlevag
# Processing Record 33 of Set 8 | lolua
# City not found. Skipping...
# Processing Record 34 of Set 8 | san blas
# Processing Record 35 of Set 8 | atar
# Processing Record 36 of Set 8 | bilma
# Processing Record 37 of Set 8 | abu dhabi
# Processing Record 38 of Set 8 | tafalla
# Processing Record 39 of Set 8 | benguela
# Processing Record 40 of Set 8 | karratha
# Processing Record 41 of Set 8 | korla
# Processing Record 42 of Set 8 | hirara
# Processing Record 43 of Set 8 | challapata
# Processing Record 44 of Set 8 | abalak
# Processing Record 45 of Set 8 | szczytno
# Processing Record 46 of Set 8 | pacific grove
# Processing Record 47 of Set 8 | rocha
# Processing Record 48 of Set 8 | nador
# Processing Record 49 of Set 8 | uray
# Processing Record 50 of Set 8 | port shepstone
# Processing Record 1 of Set 9 | mullaitivu
# City not found. Skipping...
# Processing Record 2 of Set 9 | hit
# Processing Record 3 of Set 9 | srednekolymsk
# Processing Record 4 of Set 9 | darlowo
# Processing Record 5 of Set 9 | moyale
# Processing Record 6 of Set 9 | hobyo
# Processing Record 7 of Set 9 | valle de allende
# Processing Record 8 of Set 9 | acarau
# Processing Record 9 of Set 9 | buraydah
# Processing Record 10 of Set 9 | shenzhen
# Processing Record 11 of Set 9 | salamanca
# Processing Record 12 of Set 9 | kyren
# Processing Record 13 of Set 9 | santa maria
# Processing Record 14 of Set 9 | qarqin
# Processing Record 15 of Set 9 | bereda
# Processing Record 16 of Set 9 | saumur
# Processing Record 17 of Set 9 | prince george
# Processing Record 18 of Set 9 | haverfordwest
# Processing Record 19 of Set 9 | taicheng
# Processing Record 20 of Set 9 | iroquois falls
# Processing Record 21 of Set 9 | bonnyville
# Processing Record 22 of Set 9 | ilheus
# Processing Record 23 of Set 9 | shebunino
# Processing Record 24 of Set 9 | puerto ayacucho
# Processing Record 25 of Set 9 | sabha
# Processing Record 26 of Set 9 | acari
# Processing Record 27 of Set 9 | inuvik
# Processing Record 28 of Set 9 | naze
# Processing Record 29 of Set 9 | fairmont
# Processing Record 30 of Set 9 | panaba
# Processing Record 31 of Set 9 | guerrero negro
# Processing Record 32 of Set 9 | adrar
# Processing Record 33 of Set 9 | russell
# Processing Record 34 of Set 9 | fonte boa
# Processing Record 35 of Set 9 | katobu
# Processing Record 36 of Set 9 | poum
# Processing Record 37 of Set 9 | fort nelson
# Processing Record 38 of Set 9 | nemuro
# Processing Record 39 of Set 9 | oistins
# Processing Record 40 of Set 9 | marienburg
# Processing Record 41 of Set 9 | bandarbeyla
# Processing Record 42 of Set 9 | amahai
# Processing Record 43 of Set 9 | obo
# Processing Record 44 of Set 9 | morondava
# Processing Record 45 of Set 9 | atherton
# Processing Record 46 of Set 9 | ponta delgada
# Processing Record 47 of Set 9 | boali
# Processing Record 48 of Set 9 | lompoc
# Processing Record 49 of Set 9 | lyman
# Processing Record 50 of Set 9 | nishihara
# Processing Record 1 of Set 10 | zhuhai
# Processing Record 2 of Set 10 | yumen
# Processing Record 3 of Set 10 | jinchengjiang
# City not found. Skipping...
# Processing Record 4 of Set 10 | krasnyy klyuch
# Processing Record 5 of Set 10 | katsuura
# Processing Record 6 of Set 10 | visnes
# Processing Record 7 of Set 10 | port-gentil
# Processing Record 8 of Set 10 | ribeira grande
# Processing Record 9 of Set 10 | kitami
# Processing Record 10 of Set 10 | puerto colombia
# Processing Record 11 of Set 10 | fort saint james
# Processing Record 12 of Set 10 | gore
# Processing Record 13 of Set 10 | kirakira
# Processing Record 14 of Set 10 | letlhakeng
# Processing Record 15 of Set 10 | mago
# Processing Record 16 of Set 10 | saint anthony
# Processing Record 17 of Set 10 | mahanoro
# Processing Record 18 of Set 10 | gambela
# Processing Record 19 of Set 10 | hervey bay
# Processing Record 20 of Set 10 | boca do acre
# Processing Record 21 of Set 10 | nyurba
# Processing Record 22 of Set 10 | waynesville
# Processing Record 23 of Set 10 | santana do livramento
# Processing Record 24 of Set 10 | yialos
# City not found. Skipping...
# Processing Record 25 of Set 10 | lagoa da canoa
# Processing Record 26 of Set 10 | phan rang
# City not found. Skipping...
# Processing Record 27 of Set 10 | kokkola
# Processing Record 28 of Set 10 | palembang
# Processing Record 29 of Set 10 | ketchikan
# Processing Record 30 of Set 10 | monrovia
# Processing Record 31 of Set 10 | sainte-maxime
# Processing Record 32 of Set 10 | rimbey
# Processing Record 33 of Set 10 | marquette
# Processing Record 34 of Set 10 | kahului
# Processing Record 35 of Set 10 | ingham
# Processing Record 36 of Set 10 | kapuskasing
# Processing Record 37 of Set 10 | port hedland
# Processing Record 38 of Set 10 | abbeville
# Processing Record 39 of Set 10 | kyabe
# Processing Record 40 of Set 10 | tanjong karang
# City not found. Skipping...
# Processing Record 41 of Set 10 | hofn
# Processing Record 42 of Set 10 | kota kinabalu
# Processing Record 43 of Set 10 | safaga
# Processing Record 44 of Set 10 | port blair
# Processing Record 45 of Set 10 | ushtobe
# Processing Record 46 of Set 10 | ranong
# Processing Record 47 of Set 10 | rio grande
# Processing Record 48 of Set 10 | vanimo
# Processing Record 49 of Set 10 | hvammstangi
# City not found. Skipping...
# Processing Record 50 of Set 10 | san patricio
# Processing Record 1 of Set 11 | bukan
# Processing Record 2 of Set 11 | beira
# Processing Record 3 of Set 11 | mehamn
# Processing Record 4 of Set 11 | augusta
# Processing Record 5 of Set 11 | waingapu
# Processing Record 6 of Set 11 | zhezkazgan
# Processing Record 7 of Set 11 | katherine
# Processing Record 8 of Set 11 | fairbanks
# Processing Record 9 of Set 11 | kudahuvadhoo
# Processing Record 10 of Set 11 | saint-francois
# Processing Record 11 of Set 11 | henties bay
# Processing Record 12 of Set 11 | lata
# Processing Record 13 of Set 11 | esperance
# Processing Record 14 of Set 11 | ust-koksa
# Processing Record 15 of Set 11 | camacha
# Processing Record 16 of Set 11 | tabuk
# Processing Record 17 of Set 11 | zeya
# Processing Record 18 of Set 11 | gat
# Processing Record 19 of Set 11 | merauke
# Processing Record 20 of Set 11 | cuamba
# Processing Record 21 of Set 11 | alugan
# Processing Record 22 of Set 11 | hendek
# Processing Record 23 of Set 11 | harper
# Processing Record 24 of Set 11 | campos
# Processing Record 25 of Set 11 | mount pleasant
# Processing Record 26 of Set 11 | labuan
# Processing Record 27 of Set 11 | limbang
# Processing Record 28 of Set 11 | portland
# Processing Record 29 of Set 11 | humaita
# Processing Record 30 of Set 11 | gravdal
# Processing Record 31 of Set 11 | chiquimula
# Processing Record 32 of Set 11 | san diego
# Processing Record 33 of Set 11 | totness
# Processing Record 34 of Set 11 | bur gabo
# City not found. Skipping...
# Processing Record 35 of Set 11 | rio gallegos
# Processing Record 36 of Set 11 | moranbah
# Processing Record 37 of Set 11 | flin flon
# Processing Record 38 of Set 11 | wanaka
# Processing Record 39 of Set 11 | vila franca do campo
# Processing Record 40 of Set 11 | mackay
# Processing Record 41 of Set 11 | kavaratti
# Processing Record 42 of Set 11 | jalu
# Processing Record 43 of Set 11 | solovetskiy
# City not found. Skipping...
# Processing Record 44 of Set 11 | gondar
# Processing Record 45 of Set 11 | westport
# Processing Record 46 of Set 11 | champerico
# Processing Record 47 of Set 11 | ribas do rio pardo
# Processing Record 48 of Set 11 | varhaug
# Processing Record 49 of Set 11 | nadym
# Processing Record 50 of Set 11 | zmeinogorsk
# Processing Record 1 of Set 12 | xichang
# Processing Record 2 of Set 12 | teya
# Processing Record 3 of Set 12 | dalvik
# Processing Record 4 of Set 12 | raudeberg
# Processing Record 5 of Set 12 | isangel
# Processing Record 6 of Set 12 | aykhal
# Processing Record 7 of Set 12 | ouesso
# Processing Record 8 of Set 12 | bathsheba
# Processing Record 9 of Set 12 | pitimbu
# Processing Record 10 of Set 12 | safford
# Processing Record 11 of Set 12 | goundi
# Processing Record 12 of Set 12 | coahuayana
# Processing Record 13 of Set 12 | narsaq
# Processing Record 14 of Set 12 | artyk
# City not found. Skipping...
# Processing Record 15 of Set 12 | mattru
# Processing Record 16 of Set 12 | lalomanu
# City not found. Skipping...
# Processing Record 17 of Set 12 | rio verde de mato grosso
# Processing Record 18 of Set 12 | turochak
# Processing Record 19 of Set 12 | zhangye
# Processing Record 20 of Set 12 | portsmouth
# Processing Record 21 of Set 12 | half moon bay
# Processing Record 22 of Set 12 | hay river
# Processing Record 23 of Set 12 | eibergen
# Processing Record 24 of Set 12 | aasiaat
# Processing Record 25 of Set 12 | tingrela
# City not found. Skipping...
# Processing Record 26 of Set 12 | salta
# Processing Record 27 of Set 12 | sotnikovo
# Processing Record 28 of Set 12 | aripuana
# Processing Record 29 of Set 12 | gavrilovka vtoraya
# Processing Record 30 of Set 12 | zhanatas
# City not found. Skipping...
# Processing Record 31 of Set 12 | cabra
# Processing Record 32 of Set 12 | kieta
# Processing Record 33 of Set 12 | drummondville
# Processing Record 34 of Set 12 | fethiye
# Processing Record 35 of Set 12 | niagara falls
# Processing Record 36 of Set 12 | rungata
# City not found. Skipping...
# Processing Record 37 of Set 12 | urk
# Processing Record 38 of Set 12 | coquimbo
# Processing Record 39 of Set 12 | guna
# Processing Record 40 of Set 12 | asau
# Processing Record 41 of Set 12 | halalo
# City not found. Skipping...
# Processing Record 42 of Set 12 | leningradskiy
# Processing Record 43 of Set 12 | atbasar
# Processing Record 44 of Set 12 | evensk
# Processing Record 45 of Set 12 | mandalgovi
# Processing Record 46 of Set 12 | faxinal
# Processing Record 47 of Set 12 | luanda
# Processing Record 48 of Set 12 | staryy nadym
# Processing Record 49 of Set 12 | samalaeulu
# City not found. Skipping...
# Processing Record 50 of Set 12 | makaha
# Processing Record 1 of Set 13 | honiara
# Processing Record 2 of Set 13 | kawambwa
# Processing Record 3 of Set 13 | kangaba
# Processing Record 4 of Set 13 | sao joao da barra
# Processing Record 5 of Set 13 | ondorhaan
# City not found. Skipping...
# Processing Record 6 of Set 13 | sergeyevka
# Processing Record 7 of Set 13 | klaksvik
# Processing Record 8 of Set 13 | pasni
# Processing Record 9 of Set 13 | port lincoln
# Processing Record 10 of Set 13 | muisne
# Processing Record 11 of Set 13 | nizhneyansk
# City not found. Skipping...
# Processing Record 12 of Set 13 | tomatlan
# Processing Record 13 of Set 13 | menongue
# Processing Record 14 of Set 13 | inirida
# Processing Record 15 of Set 13 | awbari
# Processing Record 16 of Set 13 | halifax
# Processing Record 17 of Set 13 | progreso
# Processing Record 18 of Set 13 | solana beach
# Processing Record 19 of Set 13 | shemursha
# Processing Record 20 of Set 13 | agadez
# Processing Record 21 of Set 13 | dabat
# Processing Record 22 of Set 13 | asyut
# Processing Record 23 of Set 13 | khanpur
# Processing Record 24 of Set 13 | trinidad
# Processing Record 25 of Set 13 | hokitika
# Processing Record 26 of Set 13 | vic
# Processing Record 27 of Set 13 | shenyang
# Processing Record 28 of Set 13 | kingaroy
# Processing Record 29 of Set 13 | brandfort
# Processing Record 30 of Set 13 | port augusta
# Processing Record 31 of Set 13 | nsanje
# Processing Record 32 of Set 13 | lazarev
# Processing Record 33 of Set 13 | kirkwall
# Processing Record 34 of Set 13 | bilibino
# Processing Record 35 of Set 13 | lake city
# Processing Record 36 of Set 13 | moroni
# Processing Record 37 of Set 13 | kuala lipis
# Processing Record 38 of Set 13 | lavrentiya
# Processing Record 39 of Set 13 | aksarka
# Processing Record 40 of Set 13 | lunsar
# Processing Record 41 of Set 13 | eskasem
# City not found. Skipping...
# Processing Record 42 of Set 13 | atambua
# Processing Record 43 of Set 13 | shingu
# Processing Record 44 of Set 13 | muscat
# Processing Record 45 of Set 13 | banda aceh
# Processing Record 46 of Set 13 | tarudant
# City not found. Skipping...
# Processing Record 47 of Set 13 | goderich
# Processing Record 48 of Set 13 | sevierville
# Processing Record 49 of Set 13 | petropavlivka
# Processing Record 50 of Set 13 | nantucket
# Processing Record 1 of Set 14 | pandan
# Processing Record 2 of Set 14 | sorvag
# City not found. Skipping...
# Processing Record 3 of Set 14 | umzimvubu
# City not found. Skipping...
# Processing Record 4 of Set 14 | mrirt
# City not found. Skipping...
# Processing Record 5 of Set 14 | silver city
# Processing Record 6 of Set 14 | mayo
# Processing Record 7 of Set 14 | katangli
# Processing Record 8 of Set 14 | hovd
# Processing Record 9 of Set 14 | ipameri
# Processing Record 10 of Set 14 | kamennogorsk
# Processing Record 11 of Set 14 | xai-xai
# Processing Record 12 of Set 14 | culasi
# Processing Record 13 of Set 14 | uvalde
# Processing Record 14 of Set 14 | san rafael
# Processing Record 15 of Set 14 | gewane
# Processing Record 16 of Set 14 | khandyga
# Processing Record 17 of Set 14 | buala
# Processing Record 18 of Set 14 | methoni
# Processing Record 19 of Set 14 | port said
# Processing Record 20 of Set 14 | zaysan
# Processing Record 21 of Set 14 | senno
# Processing Record 22 of Set 14 | baykit
# Processing Record 23 of Set 14 | los llanos de aridane
# Processing Record 24 of Set 14 | kenai
# Processing Record 25 of Set 14 | buchanan
# Processing Record 26 of Set 14 | burica
# City not found. Skipping...
# Processing Record 27 of Set 14 | komagane
# Processing Record 28 of Set 14 | uga
# Processing Record 29 of Set 14 | zemio
# Processing Record 30 of Set 14 | itaituba
# Processing Record 31 of Set 14 | jasper
# Processing Record 32 of Set 14 | zavodouspenskoye
# Processing Record 33 of Set 14 | walvis bay
# Processing Record 34 of Set 14 | tartus
# Processing Record 35 of Set 14 | road town
# Processing Record 36 of Set 14 | manggar
# Processing Record 37 of Set 14 | hami
# Processing Record 38 of Set 14 | salon-de-provence
# Processing Record 39 of Set 14 | lar gerd
# City not found. Skipping...
# Processing Record 40 of Set 14 | clyde river
# Processing Record 41 of Set 14 | mwingi
# Processing Record 42 of Set 14 | ravar
# Processing Record 43 of Set 14 | maniitsoq
# Processing Record 44 of Set 14 | qaqortoq
# Processing Record 45 of Set 14 | junin
# Processing Record 46 of Set 14 | satitoa
# City not found. Skipping...
# Processing Record 47 of Set 14 | jacareacanga
# Processing Record 48 of Set 14 | henderson
# Processing Record 49 of Set 14 | pouembout
# Processing Record 50 of Set 14 | wagar
# Processing Record 1 of Set 15 | northam
# Processing Record 2 of Set 15 | ganta
# Processing Record 3 of Set 15 | povenets
# Processing Record 4 of Set 15 | puerto narino
# Processing Record 5 of Set 15 | bata
# Processing Record 6 of Set 15 | husavik
# Processing Record 7 of Set 15 | rawson
# Processing Record 8 of Set 15 | floro
# Processing Record 9 of Set 15 | xining
# Processing Record 10 of Set 15 | vallenar
# Processing Record 11 of Set 15 | kaspiysk
# Processing Record 12 of Set 15 | marawi
# Processing Record 13 of Set 15 | takoradi
# Processing Record 14 of Set 15 | tsiroanomandidy
# Processing Record 15 of Set 15 | staunton
# Processing Record 16 of Set 15 | beian
# Processing Record 17 of Set 15 | khorixas
# Processing Record 18 of Set 15 | micheweni
# Processing Record 19 of Set 15 | luchegorsk
# Processing Record 20 of Set 15 | kulhudhuffushi
# Processing Record 21 of Set 15 | bay saint louis
# Processing Record 22 of Set 15 | tucuma
# Processing Record 23 of Set 15 | tolbazy
# Processing Record 24 of Set 15 | ban tak
# Processing Record 25 of Set 15 | aklavik
# Processing Record 26 of Set 15 | maningrida
# Processing Record 27 of Set 15 | havelock
# Processing Record 28 of Set 15 | begoro
# Processing Record 29 of Set 15 | porto novo
# Processing Record 30 of Set 15 | san jose
# Processing Record 31 of Set 15 | manicore
# Processing Record 32 of Set 15 | santa fe
# Processing Record 33 of Set 15 | tarbagatay
# Processing Record 34 of Set 15 | bosaso
# Processing Record 35 of Set 15 | jinka
# Processing Record 36 of Set 15 | mentok
# City not found. Skipping...
# Processing Record 37 of Set 15 | taguatinga
# Processing Record 38 of Set 15 | hihifo
# City not found. Skipping...
# Processing Record 39 of Set 15 | kamenskoye
# City not found. Skipping...
# Processing Record 40 of Set 15 | seymchan
# Processing Record 41 of Set 15 | mangan
# Processing Record 42 of Set 15 | abha
# Processing Record 43 of Set 15 | honningsvag
# Processing Record 44 of Set 15 | tursunzoda
# Processing Record 45 of Set 15 | paracuru
# Processing Record 46 of Set 15 | kargasok
# Processing Record 47 of Set 15 | kharar
# Processing Record 48 of Set 15 | moerai
# Processing Record 49 of Set 15 | nguruka
# Processing Record 50 of Set 15 | plettenberg bay
# Processing Record 1 of Set 16 | chateaubelair
# Processing Record 2 of Set 16 | presidencia roque saenz pena
# Processing Record 3 of Set 16 | wahran
# City not found. Skipping...
# Processing Record 4 of Set 16 | san policarpo
# Processing Record 5 of Set 16 | wa
# City not found. Skipping...
# Processing Record 6 of Set 16 | miracema do tocantins
# Processing Record 7 of Set 16 | shitanjing
# Processing Record 8 of Set 16 | mardin
# Processing Record 9 of Set 16 | pochutla
# Processing Record 10 of Set 16 | cape coast
# Processing Record 11 of Set 16 | langsa
# Processing Record 12 of Set 16 | labutta
# City not found. Skipping...
# Processing Record 13 of Set 16 | goundam
# Processing Record 14 of Set 16 | turka
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 701

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#                 City Country      Lat       Lng  Max Temp  Humidity  \
# 0            Cayenne      GF   4.9333  -52.3333     84.24        74
# 1             Sabang      ID   5.8933   95.3214     82.99        76
# 2            Ushuaia      AR -54.8000  -68.3000     29.86        86
# 3           Meulaboh      ID   4.1363   96.1285     78.24        84
# 4            Hualmay      PE -11.0964  -77.6139     67.64        78
# 5            Qaanaaq      GL  77.4840  -69.3632     33.19        89
# 6               Bara      NG  10.3744   10.7288     96.58        23
# 7             Faanui      PF -16.4833 -151.7500     78.40        68
# 8  Sao Joao Do Piaui      BR  -8.3581  -42.2467     94.82        28
# 9          Hithadhoo      MV  -0.6000   73.0833     84.07        70
#
#    Cloudiness  Wind Speed Current Description
# 0          75        9.42       broken clouds
# 1          86       17.98          light rain
# 2          75        6.91       broken clouds
# 3          95        1.86     overcast clouds
# 4          97        6.69     overcast clouds
# 5         100        2.95     overcast clouds
# 6          44        3.29    scattered clouds
# 7         100       14.58     overcast clouds
# 8          11        7.54          few clouds
# 9          82       16.64       broken clouds

# %%
# Create the output file (CSV).
output_data_file = "../Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
